# %% [markdown]
# # Table of Contents
# * [Using a lattice](#Using-a-lattice)
# 	* [Generating some random extensive variable for the threshold (`pop`) and for the attributes (`income_pp`)](#Generating-some-random-extensive-variable-for-the-threshold-%28pop%29-and-for-the-attributes-%28income_pp%29)
# * [Queen matrix](#Queen-matrix)
# * [Rook matrix](#Rook-matrix)
# * [Queen matrix: Default Max-P](#Queen-matrix:-Default-Max-P)
# * [Rook matrix: Default Max-P](#Rook-matrix:-Default-Max-P)
# * [Queen matrix: Max-P with Basic Tabu Local Search](#Queen-matrix:-Max-P-with-Basic-Tabu-Local-Search)
# * [Rook matrix: Max-P with Basic Tabu Local Search](#Rook-matrix:-Max-P-with-Basic-Tabu-Local-Search)

# %%
# %matplotlib inline

import geopandas as gpd
import numpy as np
from pysal.viz.splot.libpysal import plot_spatial_weights
from libpysal.weights import Queen, Rook
from region.max_p_regions.heuristics import MaxPRegionsHeu
from region.p_regions.azp import *

# %% [markdown]
# # Using a lattice

# %%
gdf = gpd.read_file('reg_lat_10_10.shp')

# %%
gdf.plot(edgecolor = 'black')

# %% [markdown]
# ## Generating some random extensive variable for the threshold (`pop`) and for the attributes (`income_pp`)

# %%
np.random.seed(123)
gdf['pop'] = np.random.randint(500, high=1000, size=100)

# %%
np.random.seed(123)
gdf['income_pp'] = np.random.uniform(low=50000, high=100000, size=100)

# %%
w_queen = Queen.from_dataframe(gdf)
w_rook = Rook.from_dataframe(gdf)

# %% [markdown]
# # Queen matrix

# %%
plot_spatial_weights(w_queen, gdf, figsize = (5, 5))
# Out:
# (<Figure size 360x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1e024efe668>)

# %% [markdown]
# # Rook matrix

# %%
plot_spatial_weights(w_rook, gdf, figsize = (5, 5))
# Out:
# (<Figure size 360x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1e0250026d8>)

# %%
values_gdf = gdf[['income_pp']]
spatially_extensive_attr_gdf = gdf[['pop']].values

# %% [markdown]
# # Queen matrix: Default Max-P

# %%
model = MaxPRegionsHeu()
model.fit_from_w(w_queen, values_gdf.values, spatially_extensive_attr_gdf, threshold = 10000)
gdf['labels'] = model.labels_
gdf.plot(column = 'labels', categorical = True, figsize = (10, 10), legend = True)

# %%
gdf.groupby(['labels'])['pop'].sum()
# Out:
# labels
# 0.0    11241
# 1.0    11318
# 2.0    13282
# 3.0    16188
# 4.0    13287
# 5.0    10060
# Name: pop, dtype: int32

# %% [markdown]
# # Rook matrix: Default Max-P

# %%
model = MaxPRegionsHeu()
model.fit_from_w(w_rook, values_gdf.values, spatially_extensive_attr_gdf, threshold = 10000)
gdf['labels'] = model.labels_
gdf.plot(column = 'labels', categorical = True, figsize = (10, 10), legend = True)

# %%
gdf.groupby(['labels'])['pop'].sum()
# Out:
# labels
# 0.0    15083
# 1.0    11809
# 2.0    11046
# 3.0    13956
# 4.0    10200
# 5.0    13282
# Name: pop, dtype: int32

# %% [markdown]
# # Queen matrix: Max-P with Basic Tabu Local Search

# %%
model = MaxPRegionsHeu(local_search = AZPBasicTabu())
model.fit_from_w(w_queen, values_gdf.values, spatially_extensive_attr_gdf, threshold = 10000)
gdf['labels'] = model.labels_
gdf.plot(column = 'labels', categorical = True, figsize = (10, 10), legend = True)

# %%
gdf.groupby(['labels'])['pop'].sum()
# Out:
# labels
# 0.0    14015
# 1.0    10992
# 2.0    11331
# 3.0    11431
# 4.0     6544
# 5.0    10200
# 6.0    10863
# Name: pop, dtype: int32

# %% [markdown]
# # Rook matrix: Max-P with Basic Tabu Local Search

# %%
model = MaxPRegionsHeu(local_search = AZPBasicTabu())
model.fit_from_w(w_rook, values_gdf.values, spatially_extensive_attr_gdf, threshold = 10000)
gdf['labels'] = model.labels_
gdf.plot(column = 'labels', categorical = True, figsize = (10, 10), legend = True)

# %%
gdf.groupby(['labels'])['pop'].sum()
# Out:
# labels
# 0.0    11053
# 1.0    18721
# 2.0    11691
# 3.0    10410
# 4.0    14983
# 5.0     8518
# Name: pop, dtype: int32

# %% [markdown]
# # Queen matrix: Max-P with AZP Local Search

# %%
model = MaxPRegionsHeu(local_search = AZP())
model.fit_from_w(w_queen, values_gdf.values, spatially_extensive_attr_gdf, threshold = 10000)
gdf['labels'] = model.labels_
gdf.plot(column = 'labels', categorical = True, figsize = (10, 10), legend = True)

# %%
gdf.groupby(['labels'])['pop'].sum()
# Out:
# labels
# 0.0    12693
# 1.0    15794
# 2.0    10504
# 3.0    13405
# 4.0    11403
# 5.0    11577
# Name: pop, dtype: int32

# %% [markdown]
# # Rook matrix: Max-P with AZP Local Search

# %%
model = MaxPRegionsHeu(local_search = AZP())
model.fit_from_w(w_rook, values_gdf.values, spatially_extensive_attr_gdf, threshold = 10000)
gdf['labels'] = model.labels_
gdf.plot(column = 'labels', categorical = True, figsize = (10, 10), legend = True)

# %%
gdf.groupby(['labels'])['pop'].sum()
# Out:
# labels
# 0.0    10953
# 1.0    11961
# 2.0    17902
# 3.0    11549
# 4.0    12811
# 5.0    10200
# Name: pop, dtype: int32

# %% [markdown]
# # Queen matrix: Max-P with AZP Tabu Local Search

# %%
model = MaxPRegionsHeu(local_search = AZPTabu())
model.fit_from_w(w_queen, values_gdf.values, spatially_extensive_attr_gdf, threshold = 10000)
gdf['labels'] = model.labels_
gdf.plot(column = 'labels', categorical = True, figsize = (10, 10), legend = True)

# %%
gdf.groupby(['labels'])['pop'].sum()
# Out:
# labels
# 0.0    12874
# 1.0    10251
# 2.0    11118
# 3.0    10066
# 4.0    10588
# 5.0    10426
# 6.0    10053
# Name: pop, dtype: int32

# %% [markdown]
# # Rook matrix: Max-P with AZP Tabu Local Search

# %%
model = MaxPRegionsHeu(local_search = AZPTabu())
model.fit_from_w(w_rook, values_gdf.values, spatially_extensive_attr_gdf, threshold = 10000)
gdf['labels'] = model.labels_
gdf.plot(column = 'labels', categorical = True, figsize = (10, 10), legend = True)

# %%
gdf.groupby(['labels'])['pop'].sum()
# Out:
# labels
# 0.0    13666
# 1.0    11332
# 2.0    10200
# 3.0    13525
# 4.0    11357
# 5.0    15296
# Name: pop, dtype: int32

# %% [markdown]
# # Queen matrix: Max-P with Reactive Tabu Local Search

# %%
model = MaxPRegionsHeu(local_search = AZPReactiveTabu(max_iterations = 2, k1 = 2, k2 = 2))
model.fit_from_w(w_queen, values_gdf.values, spatially_extensive_attr_gdf, threshold = 10000)
gdf['labels'] = model.labels_
gdf.plot(column = 'labels', categorical = True, figsize = (10, 10), legend = True)

# %%
gdf.groupby(['labels'])['pop'].sum()
# Out:
# labels
# 0.0    12057
# 1.0    13640
# 2.0    11342
# 3.0    15519
# 4.0     9462
# 5.0    13356
# Name: pop, dtype: int32

# %% [markdown]
# # Rook matrix: Max-P with Reactive Tabu Local Search

# %%
model = MaxPRegionsHeu(local_search = AZPReactiveTabu(max_iterations = 10, k1 = 10, k2 = 10))
model.fit_from_w(w_rook, values_gdf.values, spatially_extensive_attr_gdf, threshold = 10000)
gdf['labels'] = model.labels_
gdf.plot(column = 'labels', categorical = True, figsize = (10, 10), legend = True)

# %%
gdf.groupby(['labels'])['pop'].sum()
# Out:
# labels
# 0.0    16398
# 1.0    15179
# 2.0    12852
# 3.0    10219
# 4.0    10528
# 5.0    10200
# Name: pop, dtype: int32

# %% [markdown]
# # Queen matrix: Max-P with AZP Simulated Annealing Local Search

# %%
model = MaxPRegionsHeu(local_search = AZPSimulatedAnnealing(init_temperature=1))
model.fit_from_w(w_queen, values_gdf.values, spatially_extensive_attr_gdf, threshold = 10000)
gdf['labels'] = model.labels_
gdf.plot(column = 'labels', categorical = True, figsize = (10, 10), legend = True)

# %%
gdf.groupby(['labels'])['pop'].sum()
# Out:
# labels
# 0.0    12691
# 1.0    14388
# 2.0    11124
# 3.0    11306
# 4.0     7811
# 5.0     8700
# 6.0     9356
# Name: pop, dtype: int32

# %% [markdown]
# # Rook matrix: Max-P with AZP Simulated Annealing Local Search

# %%
model = MaxPRegionsHeu(local_search = AZPSimulatedAnnealing(init_temperature=1))
model.fit_from_w(w_rook, values_gdf.values, spatially_extensive_attr_gdf, threshold = 10000)
gdf['labels'] = model.labels_
gdf.plot(column = 'labels', categorical = True, figsize = (10, 10), legend = True)

# %%
gdf.groupby(['labels'])['pop'].sum()
# Out:
# labels
# 0.0    16694
# 1.0    11231
# 2.0    11424
# 3.0    10200
# 4.0    10530
# 5.0    15297
# Name: pop, dtype: int32
